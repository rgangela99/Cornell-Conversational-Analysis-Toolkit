# %%
import os
os.chdir('../../..')

# %%
import convokit

# %%
from convokit import Corpus, download
from convokit import HyperConvo
import numpy as np
import pickle

# %%
os.chdir('convokit/tensors')

# %%
with open('data_fixed/tensor.p', 'rb') as f:
    tensor = pickle.load(f)

# %%
with open('data_fixed/rank_to_factors.p', 'rb') as f:
    rank_to_factors = pickle.load(f)

# %%
tensor.shape
# Out:
# (18, 29487, 140)

# %%
factors = rank_to_factors[9]

# %%
factors[0].shape
# Out:
# (18, 9)

# %%
factors[1].shape
# Out:
# (29487, 9)

# %%
factors[2].shape
# Out:
# (140, 9)

# %%
with open('data_fixed/subreddits.p', 'rb') as f:
    subreddits = pickle.load(f)

# %%
from sklearn.preprocessing import Imputer, Normalizer, StandardScaler
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import pairwise_distances

# %%
import pandas as pd

# %%
df = pd.DataFrame(factors[1])

# %%
df['subreddits'] = subreddits

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.006089  0.005918 -0.004975  0.010238 -0.015951  0.004236  0.048639
# 1 -0.005069 -0.007186  0.002298  0.000849 -0.015948  0.001340 -0.062955
# 2 -0.006315 -0.008155  0.008103 -0.013465 -0.030409 -0.005532  0.033562
# 3 -0.005927 -0.000106  0.001521  0.007640 -0.013386  0.018967  0.029565
# 4 -0.006844 -0.009087  0.009199 -0.007776 -0.022354  0.016712 -0.073338
#
#           7         8           subreddits
# 0 -0.013198 -0.155252  MaliciousCompliance
# 1 -0.028132  0.007838  MaliciousCompliance
# 2  0.011911  0.127855  MaliciousCompliance
# 3 -0.032531 -0.061954  MaliciousCompliance
# 4 -0.073208 -0.039634  MaliciousCompliance

# %%
subreddit_means = df.groupby('subreddits').mean()
subreddit_df = pd.DataFrame(
        data=Normalizer().fit_transform(subreddit_means.values),
        index = subreddit_means.index
    )

# %%
subreddit_df
# Out:
#                             0         1         2         3         4  \
# subreddits
# 2007scape           -0.114861 -0.073536  0.019329  0.005453 -0.366939
# AmItheAsshole       -0.095762 -0.104449  0.000974 -0.089694 -0.280926
# Android             -0.117324 -0.056509 -0.003757  0.012023 -0.356958
# AskMen              -0.089093 -0.042902 -0.023226 -0.028629 -0.288867
# AskTrumpSupporters  -0.200637 -0.190172 -0.117617 -0.230730 -0.624411
# AskWomen            -0.105160 -0.021897 -0.073011 -0.062507 -0.371035
# Bitcoin             -0.109081 -0.068918 -0.014985 -0.022462 -0.331143
# CFB                 -0.110425 -0.042690 -0.017002  0.005151 -0.351378
# CanadaPolitics      -0.137342 -0.125569 -0.014646 -0.076435 -0.374707
# Christianity        -0.073823 -0.093810 -0.026745 -0.085186 -0.186149
# Conservative        -0.114794 -0.086894 -0.013577 -0.034368 -0.337569
# DebateReligion      -0.069968 -0.096324 -0.043222 -0.101553 -0.164763
# Diablo              -0.128126 -0.085414 -0.002394 -0.006132 -0.391620
# DotA2               -0.085920 -0.033599  0.009350  0.027174 -0.281970
# Drugs               -0.098032 -0.094069 -0.012518 -0.067666 -0.282677
# Economics           -0.122339 -0.092927 -0.003468 -0.037221 -0.347505
# Fitness             -0.135698 -0.059024 -0.052156 -0.067011 -0.447869
# Frugal              -0.104203 -0.047402  0.004075 -0.002891 -0.333375
# Games               -0.088778 -0.027855 -0.013704  0.026059 -0.281329
# Guildwars2          -0.120375 -0.075352 -0.004733 -0.025386 -0.362126
# IAmA                -0.081769 -0.061261  0.067033 -0.027272 -0.284614
# Libertarian         -0.089979 -0.087860 -0.022337 -0.058671 -0.238548
# MGTOW               -0.115651 -0.071106 -0.004699 -0.024279 -0.363957
# MMA                 -0.095371 -0.041748 -0.002075  0.016804 -0.305325
# MakeupAddiction     -0.202187 -0.099013 -0.073327 -0.147056 -0.721509
# MaliciousCompliance -0.127885 -0.081206  0.031471  0.003185 -0.417643
# Marvel              -0.098058 -0.036382 -0.010632  0.013781 -0.321002
# MensRights          -0.105140 -0.105719 -0.012781 -0.080692 -0.295675
# Minecraft           -0.134869 -0.094788  0.004190 -0.005800 -0.407037
# Music               -0.066315 -0.013313 -0.011798  0.007240 -0.221613
# ...                       ...       ...       ...       ...       ...
# nba                 -0.095787 -0.053259  0.013350  0.014931 -0.293158
# news                -0.093812 -0.051834 -0.002544 -0.009367 -0.282650
# nfl                 -0.091619 -0.038850 -0.004276  0.011621 -0.293360
# philosophy          -0.103125 -0.077089 -0.022469 -0.055213 -0.291912
# photography         -0.150959 -0.103504 -0.021623 -0.052676 -0.446012
# pics                -0.075877 -0.031949  0.001175 -0.001905 -0.250594
# pokemon             -0.096299 -0.048367 -0.022693 -0.018841 -0.319271
# pokemontrades       -0.022933 -0.052885 -0.030680 -0.059694 -0.049252
# politics            -0.079052 -0.029957 -0.010194 -0.013694 -0.257190
# programming         -0.122714 -0.061878 -0.001618  0.010211 -0.376585
# raisedbynarcissists -0.087746 -0.064287 -0.007723 -0.066833 -0.289189
# relationship_advice -0.072828 -0.080151 -0.015560 -0.075603 -0.209382
# relationships       -0.068758 -0.061848  0.059650 -0.067651 -0.268756
# science             -0.095808 -0.032061 -0.007358  0.014690 -0.299854
# sex                 -0.093403 -0.079835 -0.003178 -0.072327 -0.278673
# singapore           -0.198987 -0.072743 -0.158535 -0.139616 -0.653088
# skyrim              -0.094932 -0.061242  0.019345  0.011124 -0.294455
# soccer              -0.104482 -0.044658 -0.009816  0.009127 -0.324725
# socialism           -0.103039 -0.093629 -0.020775 -0.053490 -0.290999
# starcraft           -0.118770 -0.074823 -0.008250 -0.002305 -0.358357
# technology          -0.096150 -0.053144 -0.009012 -0.011933 -0.294842
# techsupport         -0.037632 -0.068046 -0.021764 -0.066296 -0.092359
# teenagers           -0.049350 -0.062836 -0.033605 -0.066031 -0.136442
# tifu                -0.084161 -0.038983  0.018045 -0.000231 -0.276938
# toronto             -0.134813 -0.080451 -0.018547 -0.021751 -0.407126
# trees               -0.100465 -0.064543  0.013269 -0.007503 -0.318088
# unitedkingdom       -0.126840 -0.090097 -0.011221 -0.033288 -0.382464
# videos              -0.076933 -0.030464  0.003507  0.015743 -0.246763
# worldnews           -0.106628 -0.062270 -0.003111 -0.010044 -0.316497
# wow                 -0.100186 -0.051032  0.009168  0.019698 -0.308768
#
#                             5         6         7         8
# subreddits
# 2007scape            0.184583  0.182886 -0.255548 -0.844706
# AmItheAsshole        0.180251  0.049405  0.019965 -0.926080
# Android              0.171936  0.193642 -0.246281 -0.853083
# AskMen               0.162456 -0.045283 -0.239580 -0.905305
# AskTrumpSupporters   0.256925  0.412260  0.318763 -0.359223
# AskWomen             0.173973 -0.194229 -0.403044 -0.781743
# Bitcoin              0.175915  0.144284 -0.150002 -0.893702
# CFB                  0.181496  0.107427 -0.298257 -0.853676
# CanadaPolitics       0.182323  0.359819 -0.018990 -0.809837
# Christianity         0.152431  0.092586  0.127478 -0.946081
# Conservative         0.187926  0.185380 -0.102584 -0.885296
# DebateReligion       0.146614  0.036427  0.172037 -0.945558
# Diablo               0.167241  0.307484 -0.153525 -0.822674
# DotA2                0.179235 -0.014581 -0.368027 -0.862192
# Drugs                0.158943  0.001644 -0.083992 -0.929827
# Economics            0.166373  0.288491 -0.063197 -0.859849
# Fitness              0.229948 -0.010319 -0.318738 -0.784684
# Frugal               0.168257  0.071725 -0.299733 -0.867431
# Games                0.159043  0.068751 -0.300755 -0.889300
# Guildwars2           0.188611  0.131590 -0.177321 -0.873898
# IAmA                 0.176487 -0.320298 -0.440505 -0.758641
# Libertarian          0.161360  0.170120  0.034456 -0.931221
# MGTOW                0.185507  0.149674 -0.204366 -0.865975
# MMA                  0.160574  0.024866 -0.294005 -0.884765
# MakeupAddiction      0.287243  0.336176 -0.295552 -0.344770
# MaliciousCompliance  0.197836  0.021702 -0.403349 -0.774160
# Marvel               0.165183 -0.003220 -0.364088 -0.851974
# MensRights           0.173472  0.104178 -0.017543 -0.917833
# Minecraft            0.195099  0.157959 -0.262455 -0.821705
# Music                0.154553 -0.124558 -0.357145 -0.882705
# ...                       ...       ...       ...       ...
# nba                  0.171967 -0.034514 -0.349351 -0.865353
# news                 0.159316  0.071241 -0.223099 -0.910108
# nfl                  0.169470  0.052017 -0.284438 -0.889692
# philosophy           0.162059  0.122250 -0.097123 -0.918703
# photography          0.211945  0.457495 -0.023590 -0.713828
# pics                 0.158945 -0.073746 -0.302570 -0.898982
# pokemon              0.205247 -0.093684 -0.328125 -0.852651
# pokemontrades        0.121272 -0.197125  0.076150 -0.964564
# politics             0.164645 -0.138009 -0.329940 -0.878294
# programming          0.183193  0.215108 -0.248103 -0.835346
# raisedbynarcissists  0.167276 -0.094475 -0.165891 -0.914103
# relationship_advice  0.160786 -0.075780 -0.025208 -0.951968
# relationships        0.145902 -0.334321 -0.263013 -0.841932
# science              0.151613  0.115693 -0.283424 -0.884822
# sex                  0.190664 -0.091469 -0.166293 -0.910840
# singapore            0.262698  0.497770  0.023693 -0.408186
# skyrim               0.169529 -0.015423 -0.334536 -0.871288
# soccer               0.188262  0.071742 -0.304729 -0.864878
# socialism            0.181457  0.211449  0.007037 -0.902750
# starcraft            0.175769  0.259429 -0.137782 -0.857100
# technology           0.151302  0.045491 -0.230167 -0.907104
# techsupport          0.132291 -0.177831  0.051798 -0.963715
# teenagers            0.167726 -0.093891  0.053018 -0.964236
# tifu                 0.178249 -0.162605 -0.422694 -0.823100
# toronto              0.201125  0.205039 -0.173897 -0.834297
# trees                0.189647 -0.089610 -0.334148 -0.853626
# unitedkingdom        0.173769  0.179386 -0.163108 -0.859826
# videos               0.164916 -0.116014 -0.392526 -0.858643
# worldnews            0.185287  0.163311 -0.234628 -0.876596
# wow                  0.179902  0.051347 -0.344175 -0.859122
#
# [100 rows x 9 columns]

# %%
tsne = TSNE(random_state=2018)
tsne_df = pd.DataFrame(data=tsne.fit_transform(subreddit_df.values),
                      index=subreddit_df.index)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
plt.scatter(tsne_df[0].values, tsne_df[1].values)
for i, txt in enumerate(tsne_df.index):
    plt.annotate(txt, (tsne_df.values[i,0], tsne_df.values[i,1]))
plt.show()

# %%
games = ["battlefield3", "Diablo", "DotA2", "Guildwars2", "leagueoflegends", "magicTCG", "Minecraft", "pokemon", "skyrim", "starcraft", "tf2", "wow"]
trade = ["Dota2Trade", "pokemontrades", "SteamGameSwap", "tf2trade", "Random_Acts_Of_Amazon"]
sports = ["baseball", "CFB", "hockey", "MMA", "nba", "nfl", "soccer"]

link_aggregators = ["AskReddit", "WTF", "pics", "gifs", "aww", "funny", "todayilearned",
                   "AdviceAnimals"]
relationships = ["AskMen", "AskWomen", "relationships", "relationship_advice", "OkCupid"]

plt.scatter(tsne_df[0].values, tsne_df[1].values, color="#dddddd")
plt.scatter(tsne_df[0].values, tsne_df[1].values, color=[
    "green" if l in games else
    "gold" if l in trade else
    "purple" if l in relationships else
    "red" if l in link_aggregators else
    "blue" if l in sports else
    "#00000000"
    for l in tsne_df.index])
plt.show()

# %%
dists = pairwise_distances(subreddit_df.values, metric='cosine')
flat_dists = np.ravel(dists)
idx1, idx2 = np.unravel_index(np.arange(len(flat_dists)), dists.shape)
pairwise_dist_df = pd.DataFrame.from_dict({'p1': subreddit_df.index[idx1],
                                           'p2': subreddit_df.index[idx2],
                                           'dist': flat_dists},
                                           orient='columns')

# %%
def print_nearest_neighbors(pairwise_dist_df, 
                           test_subreddits=[],
                           top_N=10):
    for subreddit in test_subreddits:
        subset_df = pairwise_dist_df[(pairwise_dist_df.p1 == subreddit)
                                 & (pairwise_dist_df.p2 != subreddit)]
        print(subreddit)
        print(subset_df.sort_values('dist')[['p2', 'dist']].head(top_N))
        print()

# %%
print_nearest_neighbors(pairwise_dist_df, ['apple', 'politics', 'leagueoflegends',
                                          'AskWomen', 'Music', 'pics',
                                          'australia', 'Random_Acts_Of_Amazon',
                                          'Bitcoin', 'MensRights'])
# Out:
# apple
#                     p2      dist
# 3898         worldnews  0.001043
# 3833  ShingekiNoKyojin  0.002017
# 3810            Diablo  0.002373
# 3840            asoiaf  0.002510
# 3886            soccer  0.002692
# 3816             Games  0.004317
# 3868            movies  0.004494
# 3875           pokemon  0.004605
# 3848            canada  0.004718
# 3874              pics  0.005199
#
# politics
#                      p2      dist
# 7766  malefashionadvice  0.002571
# 7705           AskWomen  0.002652
# 7737              anime  0.003972
# 7714            Fitness  0.007320
# 7703             AskMen  0.010323
# 7767        motorcycles  0.010736
# 7710             Diablo  0.011414
# 7704          AskReddit  0.011570
# 7798          worldnews  0.011978
# 7738              apple  0.012777
#
# leagueoflegends
#                    p2      dist
# 6478      programming  0.000234
# 6411            DotA2  0.000420
# 6472          offbeat  0.000453
# 6447         business  0.001050
# 6444         baseball  0.001440
# 6499              wow  0.001758
# 6481  rupaulsdragrace  0.001967
# 6487        starcraft  0.002368
# 6465         magicTCG  0.002542
# 6452       cringepics  0.002614
#
# AskWomen
#                     p2      dist
# 577           politics  0.002652
# 537              anime  0.003138
# 566  malefashionadvice  0.004309
# 567        motorcycles  0.005138
# 514            Fitness  0.006175
# 510             Diablo  0.007492
# 515             Frugal  0.008443
# 503             AskMen  0.009232
# 538              apple  0.009302
# 598          worldnews  0.009398
#
# Music
#                    p2      dist
# 2788       technology  0.000877
# 2723           Marvel  0.001145
# 2721              MMA  0.001796
# 2720      LifeProTips  0.002064
# 2716            Games  0.003231
# 2797           videos  0.003557
# 2781  rupaulsdragrace  0.003588
# 2786           soccer  0.003809
# 2757            funny  0.003922
# 2768           movies  0.004313
#
# pics
#                     p2      dist
# 7448            canada  0.001169
# 7433  ShingekiNoKyojin  0.001200
# 7469               nba  0.001480
# 7475           pokemon  0.001508
# 7440            asoiaf  0.001553
# 7416             Games  0.001576
# 7434     SquaredCircle  0.001681
# 7400     AdviceAnimals  0.001685
# 7468            movies  0.001828
# 7487         starcraft  0.001894
#
# australia
#                    p2      dist
# 4252       cringepics  0.001013
# 4244         baseball  0.001694
# 4299              wow  0.001807
# 4265         magicTCG  0.002294
# 4211            DotA2  0.002317
# 4274             pics  0.002429
# 4287        starcraft  0.002766
# 4216            Games  0.003057
# 4264  leagueoflegends  0.003213
# 4259             gifs  0.004170
#
# Random_Acts_Of_Amazon
#                         p2      dist
# 3209        DebateReligion  0.034370
# 3230               OkCupid  0.040337
# 3254  electronic_cigarette  0.045666
# 3222       MakeupAddiction  0.046752
# 3208          Christianity  0.052663
# 3246              buildapc  0.056048
# 3229                 NoFap  0.059081
# 3231               POLITIC  0.061666
# 3273           photography  0.063948
# 3290             teenagers  0.064106
#
# Bitcoin
#                 p2      dist
# 650     conspiracy  0.000582
# 696  unitedkingdom  0.000694
# 612          Drugs  0.001405
# 661           guns  0.001406
# 624     MensRights  0.002279
# 692           tifu  0.002295
# 617     Guildwars2  0.002593
# 628         Naruto  0.003659
# 695          trees  0.003701
# 651         cringe  0.004495
#
# MensRights
#                  p2      dist
# 2496  unitedkingdom  0.000715
# 2417     Guildwars2  0.001336
# 2467    motorcycles  0.001707
# 2492           tifu  0.002181
# 2450     conspiracy  0.002183
# 2495          trees  0.002266
# 2406        Bitcoin  0.002279
# 2449           cars  0.002407
# 2412          Drugs  0.002647
# 2485         skyrim  0.002795

# %%
num_subreddits = 7
for component_idx in range(9):
    print("For component index: {}".format(component_idx))
    
    subreddits_for_component = list(subreddit_df.sort_values(by=[component_idx])[[component_idx]].index)
    print("Lowest: {}".format(subreddits_for_component[:num_subreddits]))
    print("Highest: {}".format(subreddits_for_component[-num_subreddits:][::-1]))
    
    print()
# Out:
# For component index: 0
# Lowest: ['WTF', 'todayilearned', 'aww', 'MovieDetails', 'gifs', 'hiphopheads', 'Android']
# Highest: ['pokemontrades', 'techsupport', 'POLITIC', 'gonewild', 'buildapc', 'teenagers', 'DebateReligion']
#
# For component index: 1
# Lowest: ['pokemontrades', 'gonewild', 'techsupport', 'POLITIC', 'buildapc', 'science', 'DebateReligion']
# Highest: ['CFB', 'hiphopheads', 'WTF', 'todayilearned', 'funny', 'books', 'aww']
#
# For component index: 2
# Lowest: ['CFB', 'fantasyfootball', 'hiphopheads', 'MMA', 'WTF', 'nfl', 'aww']
# Highest: ['pokemontrades', 'gonewild', 'techsupport', 'POLITIC', 'electronic_cigarette', 'buildapc', 'teenagers']
#
# For component index: 3
# Lowest: ['gonewild', 'pokemontrades', 'POLITIC', 'techsupport', 'relationships', 'science', 'buildapc']
# Highest: ['fantasyfootball', 'CFB', 'hiphopheads', 'MMA', 'nfl', 'videos', 'soccer']
#
# For component index: 4
# Lowest: ['CFB', 'books', 'singapore', 'fantasyfootball', 'hiphopheads', 'nfl', 'malefashionadvice']
# Highest: ['relationships', 'IAmA', 'AmItheAsshole', 'tf2', 'dayz', 'relationship_advice', 'gonewild']
#
# For component index: 5
# Lowest: ['aww', 'Android', 'hiphopheads', 'WTF', 'askscience', 'todayilearned', 'hockey']
# Highest: ['pokemontrades', 'gonewild', 'POLITIC', 'Random_Acts_Of_Amazon', 'techsupport', 'DebateReligion', 'buildapc']
#
# For component index: 6
# Lowest: ['science', 'askscience', 'relationships', 'gonewild', 'pokemontrades', 'techsupport', 'TwoXChromosomes']
# Highest: ['Android', 'WTF', 'todayilearned', 'fantasyfootball', 'hiphopheads', 'hockey', 'funny']
#
# For component index: 7
# Lowest: ['Random_Acts_Of_Amazon', 'OkCupid', 'TwoXChromosomes', 'relationships', 'askscience', 'Christianity', 'photography']
# Highest: ['WTF', 'todayilearned', 'MovieDetails', 'aww', 'Android', 'rupaulsdragrace', 'wow']
#
# For component index: 8
# Lowest: ['science', 'Random_Acts_Of_Amazon', 'gonewild', 'pokemontrades', 'askscience', 'relationships', 'POLITIC']
# Highest: ['tf2', 'gaming', 'Minecraft', 'wow', 'business', 'baseball', 'skyrim']
