# %%
import os
os.chdir('../../..')

# %%
import convokit

# %%
from convokit import Corpus
import pickle
import numpy as np
import os
from tensorly.decomposition import parafac
from convokit.tensors.utils import plot_factors
from sklearn.preprocessing import StandardScaler
from collections import defaultdict, Counter
from jinja2 import Environment, FileSystemLoader
import matplotlib.pyplot as plt
import seaborn as sns
import random
import warnings

# %%
CORPUS_DIR = "longreddit_construction/long-reddit-corpus"
# CORPUS_DIR = "reddit-corpus-small"
# CORPUS_DIR =
DATA_DIR = "data_fixed"
PLOT_DIR = "html/graphs"
# hyperconv_range = range(0, 9+1)
hyperconv_range = range(3, 20+1)
rank_range = range(9, 9+1)
max_rank = max(rank_range)
anomaly_threshold = 1.5

# %%
os.chdir('convokit/tensors')

# %%
with open(os.path.join(DATA_DIR, 'tensor.p'), 'rb') as f:
    tensor = pickle.load(f)

# %%
with open(os.path.join(DATA_DIR, 'rank_to_factors.p'), 'rb') as f:
    rank_to_factors = pickle.load(f)

# %%
with open(os.path.join(DATA_DIR, 'convo_ids.p'), 'rb') as f:
    convo_ids = pickle.load(f)

# %%
tensor.shape
# Out:
# (18, 29487, 140)

# %%
factors = rank_to_factors[9]

# %%
factors[0].shape
# Out:
# (18, 9)

# %%
factors[1].shape
# Out:
# (29487, 9)

# %%
factors[2].shape
# Out:
# (140, 9)

# %%
from sklearn.preprocessing import Imputer, Normalizer, StandardScaler
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import pairwise_distances

# %%
from sklearn.manifold import TSNE
tsne = TSNE(random_state=2020, verbose=1)

# %%
print(factors[1].shape)
projected_threads = tsne.fit_transform(factors[1])
print(projected_threads.shape)
# Out:
# (29487, 9)
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 29487 samples in 0.032s...
# [t-SNE] Computed neighbors for 29487 samples in 2.887s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 29487
# [t-SNE] Computed conditional probabilities for sample 2000 / 29487
# [t-SNE] Computed conditional probabilities for sample 3000 / 29487
# [t-SNE] Computed conditional probabilities for sample 4000 / 29487
# [t-SNE] Computed conditional probabilities for sample 5000 / 29487
# [t-SNE] Computed conditional probabilities for sample 6000 / 29487
# [t-SNE] Computed conditional probabilities for sample 7000 / 29487
# [t-SNE] Computed conditional probabilities for sample 8000 / 29487
# [t-SNE] Computed conditional probabilities for sample 9000 / 29487
# [t-SNE] Computed conditional probabilities for sample 10000 / 29487
# [t-SNE] Computed conditional probabilities for sample 11000 / 29487
# [t-SNE] Computed conditional probabilities for sample 12000 / 29487
# [t-SNE] Computed conditional probabilities for sample 13000 / 29487
# [t-SNE] Computed conditional probabilities for sample 14000 / 29487
# [t-SNE] Computed conditional probabilities for sample 15000 / 29487
# [t-SNE] Computed conditional probabilities for sample 16000 / 29487
# [t-SNE] Computed conditional probabilities for sample 17000 / 29487
# [t-SNE] Computed conditional probabilities for sample 18000 / 29487
# [t-SNE] Computed conditional probabilities for sample 19000 / 29487
# [t-SNE] Computed conditional probabilities for sample 20000 / 29487
# [t-SNE] Computed conditional probabilities for sample 21000 / 29487
# [t-SNE] Computed conditional probabilities for sample 22000 / 29487
# [t-SNE] Computed conditional probabilities for sample 23000 / 29487
# [t-SNE] Computed conditional probabilities for sample 24000 / 29487
# [t-SNE] Computed conditional probabilities for sample 25000 / 29487
# [t-SNE] Computed conditional probabilities for sample 26000 / 29487
# [t-SNE] Computed conditional probabilities for sample 27000 / 29487
# [t-SNE] Computed conditional probabilities for sample 28000 / 29487
# [t-SNE] Computed conditional probabilities for sample 29000 / 29487
# [t-SNE] Computed conditional probabilities for sample 29487 / 29487
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 86.527298
# [t-SNE] KL divergence after 1000 iterations: 2.059678
# (29487, 2)

# %%
import matplotlib.pyplot as plt

# %%
import random

# %%
plt.figure(figsize=(15,15))
plt.scatter(projected_threads[:,0], projected_threads[:, 1])

for i in range(tensor.shape[1]):
    if random.random() < 0.03:
        plt.annotate(convo_ids[i], (projected_threads[i][0], projected_threads[i][1]))
    
plt.show()

# %% [markdown]
# ## What if we focus further specifically on the positive / negative threads only?

# %% [markdown]
# Since these might be most striking and therefore give us a more separated TSNE.

# %%
from collections import defaultdict, Counter

# %%
anomaly_threshold = 1.5

# %%
def get_anomalous_points(factor_full, idx):
    scaler = StandardScaler()
    factor = factor_full[:, idx]
    reshaped = factor.reshape((factor.shape[0], 1))
    scaled = scaler.fit_transform(reshaped)
    pos_pts = np.argwhere(scaled.reshape(factor.shape[0]) > anomaly_threshold).flatten()
    neg_pts = np.argwhere(scaled.reshape(factor.shape[0]) < -anomaly_threshold).flatten()
    return pos_pts, neg_pts

def generate_high_level_summary():
    # generate_plots()
    with open(os.path.join(DATA_DIR, 'rank_to_factors.p'), 'rb') as f:
        rank_to_factors = pickle.load(f)

    with open(os.path.join(DATA_DIR, 'hg_features.p'), 'rb') as f:
        liwc_features = pickle.load(f)

    with open(os.path.join(DATA_DIR, 'subreddits.p'), 'rb') as f:
        subreddits = pickle.load(f)

    time_factor = rank_to_factors[max_rank][0] # (9, 9)
    thread_factor = rank_to_factors[max_rank][1] # (10000, 9)
    feature_factor = rank_to_factors[max_rank][2] # (140, 9)
    idx_to_distinctive_threads = defaultdict(dict)
    idx_to_distinctive_features = defaultdict(dict)

    # normalizing
    subreddit_totals = Counter(subreddits)
    for idx in range(max_rank):
        pos_thread_pts, neg_thread_pts = get_anomalous_points(thread_factor, idx)
        idx_to_distinctive_threads[idx]['pos_threads'] = pos_thread_pts
        idx_to_distinctive_threads[idx]['neg_threads'] = neg_thread_pts

        pos_features, neg_features = get_anomalous_points(feature_factor, idx)
        idx_to_distinctive_features[idx]['pos_features'] = pos_features
        idx_to_distinctive_features[idx]['neg_features'] = neg_features

    return idx_to_distinctive_threads, idx_to_distinctive_features

# %%
idx_to_distinctive_threads, idx_to_distinctive_features = generate_high_level_summary()

# %%
for factor_idx, threads in idx_to_distinctive_threads.items():
    print("Factor {}".format(factor_idx+1))
    print("Number of pos threads: {}".format(len(threads['pos_threads'])))
    print("Number of neg threads: {}".format(len(threads['neg_threads'])))
    print("Positive feats: {}".format(idx_to_distinctive_features[factor_idx]['pos_features']))
    print("Negative feats: {}".format(idx_to_distinctive_features[factor_idx]['neg_features']))
    print()
# Out:
# Factor 1
# Number of pos threads: 1141
# Number of neg threads: 1890
# Positive feats: []
# Negative feats: [  0  13  37  63  67 137]
#
# Factor 2
# Number of pos threads: 2150
# Number of neg threads: 1472
# Positive feats: [  0  13  37  67 137]
# Negative feats: [ 61 131]
#
# Factor 3
# Number of pos threads: 1546
# Number of neg threads: 1430
# Positive feats: [ 63  70  83 107 137]
# Negative feats: [ 61 131]
#
# Factor 4
# Number of pos threads: 2247
# Number of neg threads: 1330
# Positive feats: [ 61  67  69 139]
# Negative feats: [  4  14  21  38  45  63  71  84  85 108 109 133]
#
# Factor 5
# Number of pos threads: 225
# Number of neg threads: 1894
# Positive feats: []
# Negative feats: [ 63  67  69 137]
#
# Factor 6
# Number of pos threads: 2452
# Number of neg threads: 987
# Positive feats: [  4  20  21  44  74  90  91 114 115]
# Negative feats: [67]
#
# Factor 7
# Number of pos threads: 1583
# Number of neg threads: 1864
# Positive feats: [  4  21  67  71  85 137]
# Negative feats: [ 20  44  61  69 131 139]
#
# Factor 8
# Number of pos threads: 779
# Number of neg threads: 2307
# Positive feats: [  4  21  71  74  85  91 137]
# Negative feats: [ 20  44  67  90 114]
#
# Factor 9
# Number of pos threads: 1715
# Number of neg threads: 2035
# Positive feats: [ 14  38  61  84 108 131]
# Negative feats: [  4  21  67  69  71  85 133 137 139]

# %%
included_threads = set()

for factor_idx, threads in idx_to_distinctive_threads.items():
    included_threads = included_threads.union(set(threads['pos_threads'])).union(threads['neg_threads'])

# %%
len(included_threads)
# Out:
# 13391

# %%
included_threads = sorted(included_threads)

# %%
factors[1][included_threads].shape
# Out:
# (13391, 9)

# %%
projected_threads = tsne.fit_transform(factors[1][included_threads])
print(projected_threads.shape)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 13391 samples in 0.011s...
# [t-SNE] Computed neighbors for 13391 samples in 0.745s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 13391
# [t-SNE] Computed conditional probabilities for sample 2000 / 13391
# [t-SNE] Computed conditional probabilities for sample 3000 / 13391
# [t-SNE] Computed conditional probabilities for sample 4000 / 13391
# [t-SNE] Computed conditional probabilities for sample 5000 / 13391
# [t-SNE] Computed conditional probabilities for sample 6000 / 13391
# [t-SNE] Computed conditional probabilities for sample 7000 / 13391
# [t-SNE] Computed conditional probabilities for sample 8000 / 13391
# [t-SNE] Computed conditional probabilities for sample 9000 / 13391
# [t-SNE] Computed conditional probabilities for sample 10000 / 13391
# [t-SNE] Computed conditional probabilities for sample 11000 / 13391
# [t-SNE] Computed conditional probabilities for sample 12000 / 13391
# [t-SNE] Computed conditional probabilities for sample 13000 / 13391
# [t-SNE] Computed conditional probabilities for sample 13391 / 13391
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.102531
# [t-SNE] KL divergence after 1000 iterations: 1.464113
# (13391, 2)

# %%
plt.figure(figsize=(15,15))
plt.scatter(projected_threads[:,0], projected_threads[:, 1])

for i in range(len(included_threads)):
    if random.random() < 0.02:
        plt.annotate(convo_ids[included_threads[i]], (projected_threads[i][0], projected_threads[i][1]))
    
plt.show()

# %%
corpus = Corpus(filename="longreddit_construction/long-reddit-corpus")

# %%
for convo in corpus.iter_conversations():
    for idx, utt in enumerate(convo.get_chronological_utterance_list()):
        utt.meta['order'] = idx

# %%
def get_convo_details(convo):
    print("Subreddit: {}".format(convo.get_utterance(convo.id).meta['subreddit']))
    convo.print_conversation_structure(lambda utt: str(utt.meta['order']) + ". " + utt.user.id, limit=20)

# %% [markdown]
# ### Tiny right cluster: focused + selective

# %%
get_convo_details(corpus.get_conversation('dpkvykx'))
# Out:
# Subreddit: Random_Acts_Of_Amazon
# 1. InThisHouse19
#     2. Yokuo
#         3. InThisHouse19
#             4. Yokuo
#                 5. InThisHouse19
#                     6. Yokuo
#                         7. InThisHouse19
#                             8. Yokuo
#                                 9. InThisHouse19
#                                     10. Yokuo
#                                         11. InThisHouse19
#                                             12. Yokuo
#                                                 13. InThisHouse19
#                                                     14. Yokuo
#                                                         15. InThisHouse19
#                                                             16. Yokuo
#                                                                 17. InThisHouse19
#                                                                     18. Yokuo
#                                                                         19. InThisHouse19
#                                                                             20. Yokuo

# %%
get_convo_details(corpus.get_conversation('e4aa708'))
# Out:
# Subreddit: DebateReligion
# 1. novagenesis
#     2. Chef_Fats
#         3. novagenesis
#             4. Chef_Fats
#                 5. novagenesis
#                     6. Chef_Fats
#                         7. novagenesis
#                             8. Chef_Fats
#                                 9. novagenesis
#                                     10. Chef_Fats
#                                         11. novagenesis
#                                             12. Chef_Fats
#                                                 13. novagenesis
#                                                     14. Chef_Fats
#                                                         15. novagenesis
#                                                             16. Chef_Fats
#                                                                 17. novagenesis
#                                                                     18. Chef_Fats
#                                                                         19. novagenesis
#                                                                             20. Chef_Fats

# %% [markdown]
# ### Top islets: dyadic + 1 extra (focused + selective)

# %%
get_convo_details(corpus.get_conversation('e3pvvql'))
# Out:
# Subreddit: news
# 1. howHardIsIt2SignUp
#     2. goosecarr
#     3. OfficialDudeGuy
#         4. howHardIsIt2SignUp
#             5. OfficialDudeGuy
#                 6. howHardIsIt2SignUp
#                     7. OfficialDudeGuy
#                         8. howHardIsIt2SignUp
#                             9. OfficialDudeGuy
#                                 10. howHardIsIt2SignUp
#                                     11. OfficialDudeGuy
#                                         12. howHardIsIt2SignUp
#                                             13. OfficialDudeGuy
#                                                 14. howHardIsIt2SignUp
#                                                     15. OfficialDudeGuy
#                                                         16. howHardIsIt2SignUp
#                                                             17. OfficialDudeGuy
#                                                                 18. howHardIsIt2SignUp
#                                                                     19. OfficialDudeGuy
#                                                                         20. howHardIsIt2SignUp

# %%
get_convo_details(corpus.get_conversation('e2m6rwi'))
# Out:
# Subreddit: Drugs
# 1. LSDkid269
#     2. FarGrape
#         3. LSDkid269
#             4. FarGrape
#             5. DudeWhereIsMyPipe
#                 6. LSDkid269
#                     7. DudeWhereIsMyPipe
#                         8. LSDkid269
#                             9. DudeWhereIsMyPipe
#                                 10. LSDkid269
#                                     11. DudeWhereIsMyPipe
#                                         12. LSDkid269
#                                             13. DudeWhereIsMyPipe
#                                                 14. LSDkid269
#                                                     15. DudeWhereIsMyPipe
#                                                         16. LSDkid269
#                                                             17. DudeWhereIsMyPipe
#                                                                 18. LSDkid269
#                                                                     19. DudeWhereIsMyPipe
#                                                                         20. LSDkid269

# %%
get_convo_details(corpus.get_conversation('dug6cc3'))
# Out:
# Subreddit: pokemontrades
# 1. trollolly
#     2. ZiR1402
#         3. trollolly
#             4. ZiR1402
#                 5. trollolly
#                 6. trollolly
#                     7. ZiR1402
#                         8. trollolly
#                             9. ZiR1402
#                                 10. trollolly
#                                     11. ZiR1402
#                                         12. trollolly
#                                             13. ZiR1402
#                                                 14. trollolly
#                                                     15. ZiR1402
#                                                         16. trollolly
#                                                             17. ZiR1402
#                                                                 18. trollolly
#                                                                     19. ZiR1402
#                                                                         20. trollolly

# %% [markdown]
# ### Right cluster: interleaved (focused + expansionary) + generalized reciprocity

# %%
get_convo_details(corpus.get_conversation('duvrxdv'))
# Out:
# Subreddit: tifu
# 1. beersykins
#     2. bruhhhhh69
#         3. Government_spy_bot
#             4. bruhhhhh69
#             5. thedoormanmusic32
#                 7. bruhhhhh69
#         8. pumpkinsnice
#             9. Geta-Ve
#             10. bruhhhhh69
#                 17. UniqueUsername171
#         11. Ess2s2
#             18. bruhhhhh69
#                 19. Ess2s2
#         13. darksugarrose
#     6. Halomir
#         14. 1111thatsfiveones
#     12. darksugarrose
#         16. bruhhhhh69
#     15. Autarch_Kade
#         20. beersykins

# %%
get_convo_details(corpus.get_conversation('dy5m157'))
# Out:
# Subreddit: ShingekiNoKyojin
# 1. MisterX217
#     2. larrycornflakies
#         4. MisterX217
#             7. PorcoBestBoy
#                 13. larrycornflakies
#             10. ConnieConman
#                 12. PorcoBestBoy
#             11. larrycornflakies
#     3. ConnieConman
#         8. MisterX217
#             14. ConnieConman
#     5. PorcoBestBoy
#         15. MisterX217
#             17. -ItsMatty
#     6. -ItsMatty
#         16. MisterX217
#             19. -ItsMatty
#     9. Hist2506
#         18. MisterX217
#     20. boss_on_air

# %%
get_convo_details(corpus.get_conversation('e1zcbou'))
# Out:
# Subreddit: singapore
# 1. i_like_cheeseburger
#     2. [deleted]
#         3. i_like_cheeseburger
#     4. morethanmeetsdi
#         5. [deleted]
#             9. morethanmeetsdi
#         6. i_like_cheeseburger
#             10. [deleted]
#                 16. i_like_cheeseburger
#                     19. undertheseea
#                         20. i_like_cheeseburger
#             15. morethanmeetsdi
#             18. undertheseea
#     7. lockheed_2000
#         11. i_like_cheeseburger
#             13. 1masterbaited
#                 17. i_like_cheeseburger
#     8. rheinl
#         12. morethanmeetsdi
#         14. i_like_cheeseburger

# %%
get_convo_details(corpus.get_conversation('e3bu3le'))
# Out:
# Subreddit: anime
# 1. AmethystItalian
#     2. Pivotfan3001
#         5. AmethystItalian
#             7. Pivotfan3001
#     3. TheRiyria
#         11. AmethystItalian
#             12. TheRiyria
#     4. Fred_MK
#     6. MetaThPr4h
#         10. AmethystItalian
#     8. Gaporigo
#         9. AmethystItalian
#     13. lilyvess
#         15. AmethystItalian
#             19. Fred_MK
#         16. sonlun96
#     14. AxtheCool
#     17. Cacophon
#         18. AmethystItalian
#     20. CommanderSevan

# %% [markdown]
# ### Leftmost cluster: interleaved (focused + expansionary) + limited/no reciprocity

# %%
get_convo_details(corpus.get_conversation('dsy5s8q'))
# Out:
# Subreddit: The_Donald
# 1. nunsinnikes
#     2. DontThinkChewSoap
#         5. LiberalTearsLMFAO
#         7. heisenburg69
#         13. Jazpan
#     3. ssentrep
#     4. dixond
#         10. RobertSparks777
#     6. HellbillyDeluxe
#         11. MichiganManMatt
#         20. faintlight
#     8. denizen42
#         16. xenophobe51
#     9. RobertSparks777
#     12. PossiblyaShitposter
#         17. xenophobe51
#             19. PossiblyaShitposter
#     14. StickitFlipit
#     15. Sirdreadick
#         18. xenophobe51

# %%
get_convo_details(corpus.get_conversation('e6kbukq'))
# Out:
# Subreddit: hockey
# 1. -whostolemyusername-
#     2. marsneedstowels
#         7. Cromasters
#             12. stramjummer
#         8. Derpadoodoo
#         18. hal64
#     3. miner88
#         4. Da-Aaron
#         5. pensbird91
#     6. 1337nerd
#     9. Tyrxgow33
#         10. MirabelleC
#             14. hamsterkill
#         11. kitchen_cents
#             13. hamsterkill
#                 16. IAmGrum
#                     17. hamsterkill
#                     19. younggun92
#             15. IAmGrum
#     20. KikiFlowers

# %%
get_convo_details(corpus.get_conversation('dypnn6w'))
# Out:
# Subreddit: mildlyinfuriating
# 1. mrskipperoo
#     2. willparry79
#     3. Sylnce
#         7. _Citizenkane
#             9. Reductive
#                 16. Deltamon
#             18. ElectronUS97
#         8. ignorantbirds
#             10. excalibron
#         12. tremens
#             13. RawketPropelled
#                 14. tremens
#         17. aman207
#     4. astutesnoot
#     5. TwatsThat
#         11. foxesareokiguess
#     6. leoleosuper
#     15. 404-Fuck-Not-Found
#     19. krathil
#     20. Emile_Zolla

# %% [markdown]
# ### Bottom cluster: focused -> both, interweaved, no reciprocity

# %%
get_convo_details(corpus.get_conversation('drda1f6'))
# Out:
# Subreddit: cringepics
# 1. Lilithiumandias
#     2. UWannaStartAFight
#         3. TodayILoled
#             18. whitesocksflipflops
#         8. critical_thought21
#             12. Im_int
#                 15. Dlrlcktd
#     4. EpicPhail60
#         5. djene_djene
#         7. nabil-xel-sahara
#             10. SpellsThatWrong
#         20. P1kachu_assassin
#     6. quakertroy
#     9. TheDerpofYork
#     11. DeckerR
#     13. AJ2KB
#     14. Fenastus
#     16. Mattjbr2
#         17. Lilithiumandias
#     19. goodjobgabe

# %%
get_convo_details(corpus.get_conversation('duxugq9'))
# Out:
# Subreddit: WTF
# 1. Honkadoo
#     2. Isaacvithurston
#         3. slightlyuseful
#             4. Brainwash_TV
#                 5. alexnader
#                 14. DRock3d
#             7. junttiana
#             9. pegicorn
#         10. vincidahk
#         15. MrPringles23
#             18. Isaacvithurston
#         19. 10z20Luka
#     6. sabrefudge
#     8. NeonBelly_
#     11. bendover912
#         16. jdayatwork
#         17. HollywooHero
#     12. RadSpaceWizard
#     13. surfANDmusic
#     20. FlusteredByBoobs

# %%
get_convo_details(corpus.get_conversation('e5oium2'))
# Out:
# Subreddit: movies
# 1. GarlicPotatoFriends
#     2. ChemEcalgineer
#         4. tourettes1992
#             5. Smallgenie549
#             6. Darddeac
#                 12. Doctor_watts
#             7. Kinoman69
#                 14. Penny-Wise_
#                 19. Mattyzooks
#             9. L1vingTribunal
#                 18. SetBrainInCmplxPlane
#             10. bob1689321
#             15. MasterofSciFi
#         8. Locke108
#         17. haywoodyamilkme
#     3. WellesCane
#     11. GREATGEEKGODofficial
#         13. eifersucht12a
#             20. WritingScreen
#     16. carolinemathildes

# %% [markdown]
# ### Central cluster: both (interleaved) -- maybe expansionary -> both?, generalized reciprocity

# %%
get_convo_details(corpus.get_conversation('dyyxkkr'))
# Out:
# Subreddit: raisedbynarcissists
# 1. NaiveEnthusiast
#     2. CheekyKarmaOwl
#     3. cbeep
#     4. decidedlyindecisive
#         7. Gnomend
#             10. bo_della
#             11. messedupbeyondbelief
#                 14. decidedlyindecisive
#                     16. messedupbeyondbelief
#                         18. decidedlyindecisive
#                             19. messedupbeyondbelief
#                                 20. decidedlyindecisive
#         13. chopstiks
#             15. decidedlyindecisive
#     5. attnpleasedont
#     6. Arcadia-ego
#     8. cryptohobo
#     9. rbnthrowawayAce
#     12. kagurawinddemon
#     17. CatSimpatico

# %%
get_convo_details(corpus.get_conversation('dywn7fb'))
# Out:
# Subreddit: tifu
# 1. Death_by_Corgi
#     2. MatthewJamesAudio
#         20. SpiritTalker
#     3. Hyperversum
#     4. MichieD
#         9. AlmightyStarfire
#     5. LastOne_Alive
#         6. Ruffblade027
#             12. EnkoNeko
#         7. aron9forever
#             8. YamnaT777
#             10. AlmightyStarfire
#             13. gromwell_grouse
#                 14. aron9forever
#             15. Joint-User
#     11. nightwica
#     16. bigshowwweeeellllll
#     17. AndroidUser8
#     18. ThingsThatAreBlue
#     19. Let_you_down

# %%
get_convo_details(corpus.get_conversation('e42jk3c'))
# Out:
# Subreddit: Christianity
# 1. nogginrocket
#     2. LegioVIFerrata
#         4. Cheeze_It
#             5. hierocles_
#                 7. Apa300
#                 14. key_lime_pie
#     3. hierocles_
#         6. strange_fate
#             8. hierocles_
#         9. Apa300
#             10. Rabbits4cats
#                 13. Apa300
#                     18. coffeefueledKM
#                         19. Rabbits4cats
#                             20. faughaballagh
#         11. Tiwazdom
#         12. nogginrocket
#         15. smileypants707
#         16. WOTWOTX2
#         17. WackedWacko

# %%
get_convo_details(corpus.get_conversation('dqtpfoj'))
# Out:
# Subreddit: CFB
# 1. XvS_W4rri0r
#     2. N-Your-Endo
#         3. wiscowonder
#             8. TheColtOfPersonality
#                 9. BorgSeduction
#                     12. Gumbeaux_
#                         20. FSUfan35
#                     16. MasterGrok
#                 13. XvS_W4rri0r
#                     15. TheColtOfPersonality
#                 17. Piano_Fingerbanger
#     4. okiewxchaser
#         7. Whosdaman
#             10. WeAreBert
#                 18. Chicken_witha_Bat
#         11. NihilisticOkie
#     5. I_CAN_SMELL_U
#     6. See_Lindsey_Run
#     14. JayRS11
#     19. antiherowes
