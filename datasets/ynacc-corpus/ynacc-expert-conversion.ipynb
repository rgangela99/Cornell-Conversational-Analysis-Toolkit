# %%
import pandas as pd
from convokit import Corpus, Utterance, Conversation
import os
os.listdir()
# Out:
# ['ydata-ynacc-v1_0_turk_annotations.tsv',
#  'ydata-ynacc-v1_0_test-ids.txt',
#  'ydata-ynacc-v1_0_IAC_annotations.tsv',
#  'ydata-ynacc-v1_0_unlabeled_conversations.tsv',
#  'ydata-ynacc-v1_0_dev-ids.txt',
#  'WebscopeReadme.txt',
#  'ydata-ynacc-v1_0_expert_annotations.tsv',
#  'README.txt',
#  'ydata-ynacc-v1_0_parentid_category.tsv',
#  'ydata-ynacc-v1_0_train-ids.txt']

# %%
os.chdir('ydata-ynacc-v1_0')

# %%
for filedir in os.listdir():
    pd.read_csv
# Out:
# ['ydata-ynacc-v1_0_turk_annotations.tsv',
#  'ydata-ynacc-v1_0_test-ids.txt',
#  'ydata-ynacc-v1_0_IAC_annotations.tsv',
#  'ydata-ynacc-v1_0_unlabeled_conversations.tsv',
#  'ydata-ynacc-v1_0_dev-ids.txt',
#  'WebscopeReadme.txt',
#  'ydata-ynacc-v1_0_expert_annotations.tsv',
#  'README.txt',
#  'ydata-ynacc-v1_0_parentid_category.tsv',
#  'ydata-ynacc-v1_0_train-ids.txt']

# %%
# basic_data = pd.read_csv('ydata-ynacc-v1_0_unlabeled_conversations.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
expert_annot = pd.read_csv('ydata-ynacc-v1_0_expert_annotations.tsv', sep='\t')

# %%
expert_annot
# Out:
#          sdid  commentindex  \
# 0       53971             2
# 1       53971             0
# 2       53971             1
# 3      135929             0
# 4      135929             1
# 5      135929             2
# 6      127970             0
# 7      127970             2
# 8      127970             1
# 9      127970             3
# 10       2228             4
# 11       2228             3
# 12       2228             2
# 13       2228             0
# 14       2228             1
# 15      68327             4
# 16      68327             2
# 17      68327             6
# 18      68327             0
# 19      68327             1
# 20      68327             5
# 21      68327             3
# 22      23896             0
# 23      23896             2
# 24      23896             1
# 25     118384             1
# 26     118384             3
# 27     118384             0
# 28     118384             2
# 29     118384             4
# ...       ...           ...
# 23353  200456             1
# 23354  200456             2
# 23355  200456             3
# 23356  213731             0
# 23357  213731             1
# 23358  213731             2
# 23359  213731             3
# 23360  213731             4
# 23361  213731             5
# 23362  202531             0
# 23363  202531             1
# 23364  202531             2
# 23365  202531             3
# 23366  202531             4
# 23367  203285             0
# 23368  203285             1
# 23369  203285             2
# 23370  203285             3
# 23371  203285             4
# 23372  203285             5
# 23373  203285             6
# 23374  203285             7
# 23375  203285             8
# 23376  210678             0
# 23377  210678             1
# 23378  210678             2
# 23379  210678             3
# 23380  202154             0
# 23381  202154             1
# 23382  202154             2
#
#                                                 headline  \
# 0        Disneyland Worker Found Dead in Haunted Mansion
# 1        Disneyland Worker Found Dead in Haunted Mansion
# 2        Disneyland Worker Found Dead in Haunted Mansion
# 3      This Old Navy Ad Featuring an Interracial Fami...
# 4      This Old Navy Ad Featuring an Interracial Fami...
# 5      This Old Navy Ad Featuring an Interracial Fami...
# 6      Patrick Brown, Jailed Because He Could Not Aff...
# 7      Patrick Brown, Jailed Because He Could Not Aff...
# 23366  00005n000000000000000000000000-e9eae328-11ac-4...  1470977411
# 23367  1471374824024-a95854fe-4ecd-4a19-bd9d-5ac942db...  1471374824
# 23368  00002b000000000000000000000000-afc0c2f3-7af0-4...  1471375491
# 23369  00003g000000000000000000000000-59f14388-125d-4...  1471375648
# 23370  00004b000000000000000000000000-6bef0dd3-818e-4...  1471375896
# 23371  00005b000000000000000000000000-5a255cb6-b85b-4...  1471382685
# 23372  00006b000000000000000000000000-80dafd2d-e76f-4...  1471399479
# 23373  00007b000000000000000000000000-38c4d25a-c324-4...  1471425044
# 23374  00008n000000000000000000000000-9593e51e-f4a4-4...  1471455107
# 23375  00009b000000000000000000000000-65b73bf1-7d8a-4...  1471618158
# 23376  1470165375479-746402da-487e-4634-85c0-e9459d07...  1470165375
# 23377  00003g000000000000000000000000-c6f1e819-a078-4...  1470170325
# 23378  00004g000000000000000000000000-2646cca8-668c-4...  1470171107
# 23379  00005g000000000000000000000000-c1fe7ab0-eb5d-4...  1470172440
# 23380  1470526815740-bb59f255-2dd1-4cad-9d3e-24fbf519...  1470526815
# 23381  00002g000000000000000000000000-b0e2f784-fd34-4...  1470528233
# 23382  00003b000000000000000000000000-d099f108-72c6-4...  1470530320
#
#        thumbs-up  thumbs-down  \
# 0            NaN          NaN
# 1            1.0          NaN
# 2            NaN          NaN
# 3           18.0          3.0
# 4            7.0          2.0
# 5            1.0          NaN
# 6           10.0          5.0
# 7            NaN          NaN
# 8            1.0          1.0
# 9            NaN          1.0
# 10           5.0          NaN
# 11           NaN         14.0
# 12           4.0          NaN
# 13          54.0          NaN
# 14           4.0          NaN
# 15           1.0          NaN
# 16           2.0          NaN
# 17           NaN          NaN
# 18          13.0          5.0
# 19           1.0          1.0
# 20           1.0          NaN
# 21           1.0          1.0
# 22           NaN          7.0
# 23           1.0          NaN
# 24           2.0          NaN
# 25           NaN          6.0
# 26           3.0          2.0
# 27          13.0          1.0
# 28           1.0          NaN
# 29           NaN          1.0
# ...          ...          ...
# 23353        1.0          1.0
# 23354        3.0          2.0
# 23355        NaN          2.0
# 23356       68.0          2.0
# 23357        3.0          2.0
# 23358        2.0          NaN
# 23359        2.0          NaN
# 23360        3.0          1.0
# 23361        4.0          NaN
# 23362       37.0          5.0
# 23363        NaN          NaN
# 23364        NaN          1.0
# 23365        NaN          1.0
# 23366        NaN          NaN
# 23367        8.0          5.0
# 23368        1.0          1.0
# 23369        1.0          1.0
# 23370        NaN          2.0
# 23371        NaN          1.0
# 23372        NaN          1.0
# 23373        NaN          1.0
# 23374        NaN          1.0
# 23375        NaN          NaN
# 23376       30.0          3.0
# 23377        2.0          1.0
# 23378        1.0          NaN
# 23379        1.0          1.0
# 23380       16.0          7.0
# 23381        NaN          5.0
# 23382        NaN          NaN
#
#                                                     text  \
# 0       These things happen , Every job has its dangers.
# 1      Sad to hear such a bad thing. Very dangerous j...
# 2      Yes..because too many houses in EU look like t...
# 3      I am frankly quite SICK of the phrase "shoved ...
# 4      Ya, I always wonder why the conservatives are ...
# 5                                         Great comment!
# 6      The result is a system where being poor become...
# 7      They are also places where you are supposed no...
# 8      Stop trying to make sense, it only confuses pe...
# 9      Madd...sorry - I can't help it. Grim....are yo...
# 10     You have to click on the link to go to Cosmo. ...
# 11            It's on the Cosmopolitan article you dolt.
# 12                        lol i thought it's my computer
# 13     Is it just my computer or is there not a singl...
# 14     THANK YOU!!!!!!!!!!!!!!!! So annoying.. journa...
# 15     At 16 I'd risk my left testicle for an A in En...
# 16     So wish I would of been a "victim".. Id still ...
# 17     Look up teacher "Michelle Yeh" guys. Would've ...
# 18     I know this was probably the best thing that e...
# 19     Man, if she is stupid enough, to let a kid kno...
# 20     Neil, who are you kidding? At 16 you would hav...
# 21     Let's not forget that she might also have a di...
# 22     This author is a schmuck. Pepe is not even Bra...
# 23     hey ANG you are wrong PEPE was born in BRASIL,...
# 24     You are the Schmuck look things up before you ...
# 25     Ghrelin is produced by your fat cells. You can...
# 26     It's the mind that controls the over eating. I...
# 27     I had a gastric sleeve done a couple of years ...
# 28     There is a book called, "A Pound of Cure" writ...
# 29     That is part of why Dr. Now makes the candidat...
# ...                                                  ...
# 23353  Really? That's all the KCUF you got? Talk abou...
# 23354  When someone says, "I could stand in the middl...
# 23355  Nice job at deflection. You just confirmed you...
# 23356  I hope this dude puts on about 20 more pounds ...
# 23357  Dude is quite buff actually...check him out on...
# 23358  It's the suit. Does not fit him well and it's ...
# 23359                        Fire the photographer then.
# 23360  you obviously never saw teen wolf! he is total...
# 23361  You guys are apologists for Tyler. He's a grea...
# 23362  As I've said at least a dozen times now, let's...
# 23363  Show me the law statues that say it's illegal ...
# 23364  Matt. there may not be a law against exiting y...
# 23365  Matt-- The fact that you called it "statues" i...
# 23366  Rich- forgive my phone error. 3 times. J- She ...
# 23367  People that believe in climate change aren't a...
# 23368  Well, TomR, it's because nowhere else in the w...
# 23369  It isn't a matter of believing in Climate Chan...
# 23370  Finally a sane person..Follow the money people...
# 23371  @USERNAME - I understand what you're saying, b...
# 23372  What money? The money is coming from the hydro...
# 23373  @USERNAME - What money? Are you that awesomely...
# 23374  Thanks for providing oil corporation figures, ...
# 23375  @USERNAME - I hope Miami doesn't drown. And I ...
# 23376  This narcissistic lunatic died because of her ...
# 23377  Well, vivkietoria, here is to bad behavior:Whe...
# 23378  The police engage suspect that demonstrate sig...
# 23379  Well, folks, each case has to be addressed ind...
# 23380      Brazilian fans suck as much as their country.
# 23381  Brazilian fans are just like fans of any other...
# 23382                  You sound like a stupid brazilian
#
#                                                 parentid constructiveclass  \
# 0      1459879464596-a3771c05-fd2e-4f44-a26a-23baec3b...      Constructive
# 1                                                    NaN      Constructive
# 2      1459879464596-a3771c05-fd2e-4f44-a26a-23baec3b...      Constructive
# 3                                                    NaN  Not constructive
# 4      1462203719963-3eeffb02-faae-4b51-9174-704c57e6...  Not constructive
# 5      1462203719963-3eeffb02-faae-4b51-9174-704c57e6...  Not constructive
# 6                                                    NaN  Not constructive
# 7      1461069703997-4fe466e4-91e3-4095-a64b-5d89e8a3...  Not constructive
# 23373  1471374824024-a95854fe-4ecd-4a19-bd9d-5ac942db...      Constructive
# 23374  1471374824024-a95854fe-4ecd-4a19-bd9d-5ac942db...      Constructive
# 23375  1471374824024-a95854fe-4ecd-4a19-bd9d-5ac942db...      Constructive
# 23376                                                NaN               NaN
# 23377  1470165375479-746402da-487e-4634-85c0-e9459d07...               NaN
# 23378  1470165375479-746402da-487e-4634-85c0-e9459d07...               NaN
# 23379  1470165375479-746402da-487e-4634-85c0-e9459d07...               NaN
# 23380                                                NaN  Not constructive
# 23381  1470526815740-bb59f255-2dd1-4cad-9d3e-24fbf519...  Not constructive
# 23382  1470526815740-bb59f255-2dd1-4cad-9d3e-24fbf519...  Not constructive
#
#                  sd_agreement  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3        Agreement throughout
# 4        Agreement throughout
# 5        Agreement throughout
# 6      Continual disagreement
# 7      Continual disagreement
# 8      Continual disagreement
# 9      Continual disagreement
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15     Continual disagreement
# 16     Continual disagreement
# 17     Continual disagreement
# 18     Continual disagreement
# 19     Continual disagreement
# 20     Continual disagreement
# 21     Continual disagreement
# 22     Continual disagreement
# 23     Continual disagreement
# 24     Continual disagreement
# 25                        NaN
# 26                        NaN
# 27                        NaN
# 28                        NaN
# 29                        NaN
# ...                       ...
# 23353  Continual disagreement
# 23354  Continual disagreement
# 23355  Continual disagreement
# 23356  Continual disagreement
# 23357  Continual disagreement
# 23358  Continual disagreement
# 23359  Continual disagreement
# 23360  Continual disagreement
# 23361  Continual disagreement
# 23362  Continual disagreement
# 23363  Continual disagreement
# 23364  Continual disagreement
# 23365  Continual disagreement
# 23366  Continual disagreement
# 23367  Continual disagreement
# 23368  Continual disagreement
# 23369  Continual disagreement
# 23370  Continual disagreement
# 23371  Continual disagreement
# 23372  Continual disagreement
# 23373  Continual disagreement
# 23374  Continual disagreement
# 23375  Continual disagreement
# 23376                     NaN
# 23377                     NaN
# 23378                     NaN
# 23379                     NaN
# 23380  Continual disagreement
# 23381  Continual disagreement
# 23382  Continual disagreement
#
#                                                  sd_type sentiment  \
# 0                                    Positive/respectful  negative
# 1                                    Positive/respectful     mixed
# 2                                    Positive/respectful   neutral
# 3                                   Off-topic/digression  negative
# 4                                   Off-topic/digression   neutral
# 5                                   Off-topic/digression  positive
# 6                         Argumentative (back and forth)   neutral
# 7                         Argumentative (back and forth)   neutral
# 8                         Argumentative (back and forth)  negative
# 9                         Argumentative (back and forth)   neutral
# 10                                                   NaN   neutral
# 11                                                   NaN  negative
# 12                                                   NaN   neutral
# 13                                                   NaN   neutral
# 14                                                   NaN   neutral
# 15                        Argumentative (back and forth)   neutral
# 16                        Argumentative (back and forth)   neutral
# 17                        Argumentative (back and forth)  negative
# 18                        Argumentative (back and forth)   neutral
# 19                        Argumentative (back and forth)  negative
# 20                        Argumentative (back and forth)  negative
# 21                        Argumentative (back and forth)   neutral
# 22                                                   NaN  negative
# 23                                                   NaN   neutral
# 24                                                   NaN  negative
# 25                                   Positive/respectful   neutral
# 26                                   Positive/respectful   neutral
# 27                                   Positive/respectful   neutral
# 28                                   Positive/respectful   neutral
# 29                                   Positive/respectful   neutral
# ...                                                  ...       ...
# 23353  Argumentative (back and forth),Flamewar (insul...  negative
# 23354  Argumentative (back and forth),Flamewar (insul...  negative
# 23355  Argumentative (back and forth),Flamewar (insul...  negative
# 23356                     Argumentative (back and forth)  negative
# 23357                     Argumentative (back and forth)   neutral
# 23358                     Argumentative (back and forth)   neutral
# 23359                     Argumentative (back and forth)  negative
# 23360                     Argumentative (back and forth)  negative
# 23361                     Argumentative (back and forth)  negative
# 23362                     Argumentative (back and forth)  negative
# 23363                     Argumentative (back and forth)  negative
# 23364                     Argumentative (back and forth)  negative
# 23365                     Argumentative (back and forth)  negative
# 23366                     Argumentative (back and forth)   neutral
# 23367                     Argumentative (back and forth)  negative
# 23368                     Argumentative (back and forth)  negative
# 23369                     Argumentative (back and forth)  negative
# 23370                     Argumentative (back and forth)  negative
# 23371                     Argumentative (back and forth)  negative
# 23372                     Argumentative (back and forth)  negative
# 23373                     Argumentative (back and forth)  negative
# 23374                     Argumentative (back and forth)  negative
# 23375                     Argumentative (back and forth)  negative
# 23376                                                NaN  negative
# 23377                                                NaN  negative
# 23378                                                NaN  negative
# 23379                                                NaN  negative
# 23380                     Argumentative (back and forth)  negative
# 23381                     Argumentative (back and forth)  negative
# 23382                     Argumentative (back and forth)  negative
#
#                      tone             commentagreement  \
# 0                     NaN  Disagreement with commenter
# 1                     NaN                          NaN
# 2             Informative                          NaN
# 3                    Mean                          NaN
# 4               Sarcastic     Agreement with commenter
# 5                     NaN     Agreement with commenter
# 6                     NaN                          NaN
# 7               Sarcastic  Disagreement with commenter
# 8                    Mean  Disagreement with commenter
# 9               Sarcastic  Disagreement with commenter
# 10                    NaN              Adjunct opinion
# 11                   Mean  Disagreement with commenter
# 12                    NaN     Agreement with commenter
# 13                    NaN                          NaN
# 14                    NaN              Adjunct opinion
# 15                    NaN  Disagreement with commenter
# 16                  Funny  Disagreement with commenter
# 17              Sarcastic                          NaN
# 18            Informative                          NaN
# 19                    NaN                          NaN
# 20                    NaN  Disagreement with commenter
# 21                    NaN              Adjunct opinion
# 22                   Mean                          NaN
# 23              Sarcastic  Disagreement with commenter
# 24                   Mean  Disagreement with commenter
# 25            Informative  Disagreement with commenter
# 26                    NaN              Adjunct opinion
# 27                    NaN                          NaN
# 28                    NaN              Adjunct opinion
# 29                    NaN              Adjunct opinion
# ...                   ...                          ...
# 23353       Controversial  Disagreement with commenter
# 23354       Controversial  Disagreement with commenter
# 23355      Mean,Sarcastic  Disagreement with commenter
# 23356                Mean                          NaN
# 23357                 NaN  Disagreement with commenter
# 23358                 NaN  Disagreement with commenter
# 23359          Mean,Funny                          NaN
# 23360                Mean  Disagreement with commenter
# 23361          Mean,Funny                          NaN
# 23362       Controversial                          NaN
# 23363          Mean,Funny                          NaN
# 23364       Controversial  Disagreement with commenter
# 23365                Mean                          NaN
# 23366                 NaN                          NaN
# 23367       Controversial                          NaN
# 23368       Controversial  Disagreement with commenter
# 23369       Controversial  Disagreement with commenter
# 23370       Controversial                          NaN
# 23371       Controversial  Disagreement with commenter
# 23372       Controversial  Disagreement with commenter
# 23373  Controversial,Mean  Disagreement with commenter
# 23374          Mean,Funny                          NaN
# 23375          Mean,Funny                          NaN
# 23376  Controversial,Mean                          NaN
# 23377                 NaN                          NaN
# 23378       Controversial                          NaN
# 23379       Controversial  Disagreement with commenter
# 23380                Mean                          NaN
# 23381       Controversial                          NaN
# 23382                Mean                          NaN
#
#                                        topic  \
# 0                     Off-topic with article
# 1                     Off-topic with article
# 2                     Off-topic with article
# 3                     Off-topic with article
# 4                     Off-topic with article
# 5                     Off-topic with article
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN
# 25                    Off-topic with article
# 26                                       NaN
# 27                            Personal story
# 28                            Personal story
# 29                                       NaN
# ...                                      ...
# 23353                                    NaN
# 23354                                    NaN
# 23355                 Off-topic with article
# 23356                                    NaN
# 23357                 Off-topic with article
# 23358                 Off-topic with article
# 23359                 Off-topic with article
# 23360                 Off-topic with article
# 23361                 Off-topic with article
# 23362                                    NaN
# 23363                                    NaN
# 23364                 Off-topic with article
# 23365                 Off-topic with article
# 23366                 Off-topic with article
# 23367                                    NaN
# 23368                 Off-topic with article
# 23369                 Off-topic with article
# 23370                                    NaN
# 23371                 Off-topic with article
# 23372                 Off-topic with article
# 23373                 Off-topic with article
# 23374                 Off-topic with article
# 23375                 Off-topic with article
# 23376                                    NaN
# 23377  Off-topic with article,Personal story
# 23378                 Off-topic with article
# 23379                 Off-topic with article
# 23380                                    NaN
# 23381                                    NaN
# 23382                 Off-topic with article
#
#                            intendedaudience  persuasiveness
# 0             Reply to a specific commenter  Not persuasive
# 1      Broadcast message / general audience  Not persuasive
# 2             Reply to a specific commenter  Not persuasive
# 3      Broadcast message / general audience      Persuasive
# 4             Reply to a specific commenter  Not persuasive
# 5      Broadcast message / general audience  Not persuasive
# 6      Broadcast message / general audience      Persuasive
# 7             Reply to a specific commenter      Persuasive
# 8             Reply to a specific commenter      Persuasive
# 9             Reply to a specific commenter  Not persuasive
# 10            Reply to a specific commenter  Not persuasive
# 11            Reply to a specific commenter  Not persuasive
# 12            Reply to a specific commenter  Not persuasive
# 13     Broadcast message / general audience  Not persuasive
# 14            Reply to a specific commenter  Not persuasive
# 15     Broadcast message / general audience      Persuasive
# 16     Broadcast message / general audience  Not persuasive
# 17     Broadcast message / general audience      Persuasive
# 18     Broadcast message / general audience      Persuasive
# 19     Broadcast message / general audience      Persuasive
# 20            Reply to a specific commenter      Persuasive
# 21     Broadcast message / general audience      Persuasive
# 22     Broadcast message / general audience      Persuasive
# 23            Reply to a specific commenter      Persuasive
# 24            Reply to a specific commenter      Persuasive
# 25            Reply to a specific commenter      Persuasive
# 26     Broadcast message / general audience  Not persuasive
# 27     Broadcast message / general audience  Not persuasive
# 28            Reply to a specific commenter      Persuasive
# 29     Broadcast message / general audience      Persuasive
# ...                                     ...             ...
# 23353         Reply to a specific commenter  Not persuasive
# 23354         Reply to a specific commenter      Persuasive
# 23355         Reply to a specific commenter  Not persuasive
# 23356  Broadcast message / general audience  Not persuasive
# 23357         Reply to a specific commenter  Not persuasive
# 23358         Reply to a specific commenter  Not persuasive
# 23359         Reply to a specific commenter  Not persuasive
# 23360         Reply to a specific commenter  Not persuasive
# 23361  Broadcast message / general audience  Not persuasive
# 23362  Broadcast message / general audience  Not persuasive
# 23363  Broadcast message / general audience  Not persuasive
# 23364         Reply to a specific commenter  Not persuasive
# 23365         Reply to a specific commenter  Not persuasive
# 23366         Reply to a specific commenter  Not persuasive
# 23367  Broadcast message / general audience  Not persuasive
# 23368         Reply to a specific commenter  Not persuasive
# 23369         Reply to a specific commenter  Not persuasive
# 23370  Broadcast message / general audience  Not persuasive
# 23371         Reply to a specific commenter  Not persuasive
# 23372         Reply to a specific commenter  Not persuasive
# 23373         Reply to a specific commenter  Not persuasive
# 23374         Reply to a specific commenter  Not persuasive
# 23375         Reply to a specific commenter  Not persuasive
# 23376  Broadcast message / general audience  Not persuasive
# 23377         Reply to a specific commenter  Not persuasive
# 23378         Reply to a specific commenter  Not persuasive
# 23379         Reply to a specific commenter  Not persuasive
# 23380  Broadcast message / general audience  Not persuasive
# 23381  Broadcast message / general audience  Not persuasive
# 23382         Reply to a specific commenter  Not persuasive
#
# [23383 rows x 20 columns]

# %%
def validate_data(d):
    if d == float('nan'):
        return None
    else:
        return d

# %%
expert_annot.shape
# Out:
# (23383, 20)

# %%
from convokit import Speaker

# %%
speakers = {x: Speaker(id=x) for x in expert_annot['guid']}

# %%
expert_annot[(expert_annot.sdid==53971) & (expert_annot.commentindex==2-1)]['commentid'].iloc[0]
# Out:
# '00002n000000000000000000000000-1c30b878-b717-4e9a-9872-2ce2906ce783'

# %%
expert_annot.head()
# Out:
#      sdid  commentindex                                           headline  \
# 0   53971             2    Disneyland Worker Found Dead in Haunted Mansion
# 1   53971             0    Disneyland Worker Found Dead in Haunted Mansion
# 2   53971             1    Disneyland Worker Found Dead in Haunted Mansion
# 3  135929             0  This Old Navy Ad Featuring an Interracial Fami...
# 4  135929             1  This Old Navy Ad Featuring an Interracial Fami...
#
#                                                  url                  guid  \
# 0  http://www.cosmopolitan.com/lifestyle/news/a56...  rjrPtwH5oVVuQnEXX3hf
# 1  http://www.cosmopolitan.com/lifestyle/news/a56...  VaW6HEsuOFUAIBqjw1k~
# 2  http://www.cosmopolitan.com/lifestyle/news/a56...  uwQePj970KaMZuW3~9Q9
# 3  http://mic.com/articles/142323/this-old-navy-a...  fixyWJivQjEQtPLLVXsu
# 4  http://mic.com/articles/142323/this-old-navy-a...  _TDnK715vO5y0OzZz_n4
#
#                                            commentid   timestamp  thumbs-up  \
# 0  00003n000000000000000000000000-ed2ae6d0-32ac-4...  1459917444        NaN
# 1  1459879464596-a3771c05-fd2e-4f44-a26a-23baec3b...  1459879464        1.0
# 2  00002n000000000000000000000000-1c30b878-b717-4...  1459881644        NaN
# 3  1462203719963-3eeffb02-faae-4b51-9174-704c57e6...  1462203719       18.0
# 4  00002I000000000000000000000000-7ef2ac58-bd84-4...  1462204643        7.0
#
#    thumbs-down                                               text  \
# 0          NaN   These things happen , Every job has its dangers.
# 1          NaN  Sad to hear such a bad thing. Very dangerous j...
# 2          NaN  Yes..because too many houses in EU look like t...
# 3          3.0  I am frankly quite SICK of the phrase "shoved ...
# 4          2.0  Ya, I always wonder why the conservatives are ...
#
#                                             parentid constructiveclass  \
# 0  1459879464596-a3771c05-fd2e-4f44-a26a-23baec3b...      Constructive
# 1                                                NaN      Constructive
# 2  1459879464596-a3771c05-fd2e-4f44-a26a-23baec3b...      Constructive
# 3                                                NaN  Not constructive
# 4  1462203719963-3eeffb02-faae-4b51-9174-704c57e6...  Not constructive
#
#            sd_agreement               sd_type sentiment         tone  \
# 0                   NaN   Positive/respectful  negative          NaN
# 1                   NaN   Positive/respectful     mixed          NaN
# 2                   NaN   Positive/respectful   neutral  Informative
# 3  Agreement throughout  Off-topic/digression  negative         Mean
# 4  Agreement throughout  Off-topic/digression   neutral    Sarcastic
#
#               commentagreement                   topic  \
# 0  Disagreement with commenter  Off-topic with article
# 1                          NaN  Off-topic with article
# 2                          NaN  Off-topic with article
# 3                          NaN  Off-topic with article
# 4     Agreement with commenter  Off-topic with article
#
#                        intendedaudience  persuasiveness
# 0         Reply to a specific commenter  Not persuasive
# 1  Broadcast message / general audience  Not persuasive
# 2         Reply to a specific commenter  Not persuasive
# 3  Broadcast message / general audience      Persuasive
# 4         Reply to a specific commenter  Not persuasive

# %%
data['thumbs-up']
# Out:
# nan

# %%
import math

# %%
utts_data = dict()
for row in expert_annot.iterrows():
    data = row[1]
    if data.commentindex == 0:
        reply_to = None
    else:
        try:
            subset = expert_annot[(expert_annot.sdid==data.sdid)]
            reply_to = subset[subset.commentindex==data.commentindex-1]['commentid'].iloc[0]
        except IndexError:
            print(f"{data.sdid} {data.commentindex}")
    if isinstance(data.parentid, float) and math.isnan(data.parentid):
        convo_id = data.commentid
    else:
        convo_id = data.parentid
    utt_data = {'sdid': data.sdid,
                'headline': data.headline,
                'url': data.url,
                'speaker': speakers[data.guid],
                'utt_id': data.commentid,
                'timestamp': data.timestamp,
                'text': data.text,
                'reply_to': reply_to,
                'conversation_id': convo_id
#                 'thumbsup': data['thumbs-up'],
#                 'thumbsdown': data['thumbs-down']
               }
    utts_data[data.commentid] = utt_data
# Out:
# 90808 3
# 90808 3
# 90808 3

# %%
len(utts_data)
# Out:
# 9160

# %% [markdown]
# The conversation at sdid 90808 is incomplete.

# %%
utts = []
for utt_id, utt_data in utts_data.items():
    if utt_data['sdid'] == 90808: continue
    utt = Utterance(id=utt_data['utt_id'], speaker=utt_data['speaker'], timestamp=utt_data['timestamp'],
                   text=utt_data['text'], reply_to=utt_data['reply_to'], conversation_id=utt_data['conversation_id'])
    utts.append(utt)

# %%
from convokit import Corpus

# %%
corpus = Corpus(utterances=utts)

# %%
corpus.print_summary_stats()
# Out:
# Number of Speakers: 6402
# Number of Utterances: 9156
# Number of Conversations: 1399

# %%
for convo in corpus.iter_conversations():
    if not convo.check_integrity(verbose=False):
        print(convo.id)

# %%
corpus.random_conversation().print_conversation_structure(lambda utt: utt.speaker.id + "\n")
# Out:
# UpzTRElEU_07fqw_aNu3
#
#     1DydgeuoctOz82hkxudm
#
#         UpzTRElEU_07fqw_aNu3
#
#             1DydgeuoctOz82hkxudm
#
#                 UpzTRElEU_07fqw_aNu3
#
#                     1DydgeuoctOz82hkxudm

# %%
corpus.dump('basic-version', base_path='.')

# %%
corpus.print_summary_stats()
# Out:
# Number of Speakers: 6402
# Number of Utterances: 9156
# Number of Conversations: 1399

# %% [markdown]
# ## Adding metadata

# %%
corpus = Corpus('basic-version')

# %%
for convo in corpus.iter_conversations():
    data = utts_data[convo.id]
    keys = ['url', 'headline', 'sdid']
    for k in keys:
        convo.add_meta(k, data[k])

# %%
corpus.random_conversation().meta
# Out:
# {'url': 'https://tvline.com/2016/04/05/michael-weatherly-leaving-ncis-storyline-dinozzo-exit/',
#  'headline': 'Michael Weatherly Leaving NCIS: Did We Just Find Out How Tony Will Exit?',
#  'sdid': 125956}

# %%
corpus.random_utterance().id
# Out:
# '00005n000000000000000000000000-d081cf91-59dd-4435-b89d-fc6c7ae822b0'

# %% [markdown]
#      1  sdid - subdialogue ID
#      2  commentindex - position of the comment as it appears in the subdialogue
#      3  headline - headline of the article
#      4  url - URL of the original article
#      5  guid  - encrypted user id
#      6  commentid - comment id
#      7  timestamp - timestamp of the comment
#      8  thumbs-up - comment level thumbsup
#      9  thumbs-down - comment level thumbsdown
#      10 text  - text of the comment
#      11 parentid - ID associated with the first comment of the subdialogue
#      12 constructiveclass - Constructive, Not constructive
#      13 sd_agreement  - Agreement throughout, Continual disagreement, Agreement to disagreement, Disagreement to agreement
#      14 sd_type - Argumentative (back and forth), Flamewar (insulting), NA, Not persuasive, Off-topic/digression, Personal stories, Positive/respectful, Snarky/humorous
#      15 sentiment - Mixed, Neutral, Negative, Positive
#      16 tone - Controversial, Sarcastic, Informative
#      17 commentagreement - Agree, Disagree, Adjunction Opinion
#      18 topic - Offtopic with article, offtopic with conversation
#      19 intendedaudience - Broadcast, Reply
#      20 persuasiveness - Persuasive, Not persuasive

# %%
expert_annot[expert_annot.commentid == corpus.random_utterance().id]
# Out:
#        sdid  commentindex                                           headline  \
# 260   68273             3  English Teacher Charged With Sexual Assault of...
# 775   68273             3  English Teacher Charged With Sexual Assault of...
# 1764  68273             3  English Teacher Charged With Sexual Assault of...
#
#                                                     url                  guid  \
# 260   http://www.insideedition.com/headlines/15888-e...  SGoApo4dLLXZvY83tDAX
# 775   http://www.insideedition.com/headlines/15888-e...  SGoApo4dLLXZvY83tDAX
# 1764  http://www.insideedition.com/headlines/15888-e...  SGoApo4dLLXZvY83tDAX
#
#                                               commentid   timestamp  \
# 260   00004n000000000000000000000000-51ca6e2b-243b-4...  1460819691
# 775   00004n000000000000000000000000-51ca6e2b-243b-4...  1460819691
# 1764  00004n000000000000000000000000-51ca6e2b-243b-4...  1460819691
#
#       thumbs-up  thumbs-down                                      text  \
# 260         4.0          1.0  russell, c'mon, you're better than that.
# 775         4.0          1.0  russell, c'mon, you're better than that.
# 1764        4.0          1.0  russell, c'mon, you're better than that.
#
#                                                parentid constructiveclass  \
# 260   1460818837098-c6d3ff5e-f271-4f00-8fc5-935aa542...  Not constructive
# 775   1460818837098-c6d3ff5e-f271-4f00-8fc5-935aa542...  Not constructive
# 1764  1460818837098-c6d3ff5e-f271-4f00-8fc5-935aa542...  Not constructive
#
#                 sd_agreement  \
# 260   Continual disagreement
# 775   Continual disagreement
# 1764  Continual disagreement
#
#                                                 sd_type sentiment  \
# 260                Snarky/humorous,Flamewar (insulting)  positive
# 775   Argumentative (back and forth),Off-topic/digre...   neutral
# 1764                                    Snarky/humorous  negative
#
#                        tone             commentagreement  \
# 260   Sympathetic,Sarcastic  Disagreement with commenter
# 775                   Funny  Disagreement with commenter
# 1764                    NaN  Disagreement with commenter
#
#                                                   topic  \
# 260                              Off-topic with article
# 775   Off-topic with conversation,Off-topic with art...
# 1764                                                NaN
#
#                    intendedaudience  persuasiveness
# 260   Reply to a specific commenter  Not persuasive
# 775   Reply to a specific commenter             NaN
# 1764  Reply to a specific commenter  Not persuasive

# %%
corpus.get_utterance('00003n000000000000000000000000-19e62029-c449-412c-835a-5510b4ee8c65')
# Out:
# Utterance({'obj_type': 'utterance', '_owner': <convokit.model.corpus.Corpus object at 0x13ae25790>, 'meta': {}, '_id': '00003n000000000000000000000000-19e62029-c449-412c-835a-5510b4ee8c65', 'speaker': Speaker({'obj_type': 'speaker', '_owner': <convokit.model.corpus.Corpus object at 0x13ae25790>, 'meta': {}, '_id': 'r88CmTiCLmRLSBMVRQOT'}), 'conversation_id': '1461753212853-1effe7e2-6c15-494c-bf4a-68006ad1e05e', '_root': '1461753212853-1effe7e2-6c15-494c-bf4a-68006ad1e05e', 'reply_to': '00002n000000000000000000000000-e7f63a66-9fd9-4cb1-8edd-2bf17964c332', 'timestamp': 1461756899, 'text': "Women can have sex, too. As much or as little as they like and with as many or as few partners as they like. It's each persons responsibility to know what the boundaries of their current relationship is and to not go past them. If a woman is in a supposedly monogamous relationship, it is her responsibility not to sleep with other people. If a man is in a supposedly monogamous relationship, it is his responsibility not to sleep with other people. It really is that simple."})

# %%
corpus.get_utterance('53453')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-199-cfdce85dafbc> in <module>
# ----> 1 corpus.get_utterance('53453')
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/convokit/model/corpus.py in get_utterance(self, utt_id)
#     212                 :return: Utterance
#     213 		"""
# --> 214         return self.utterances[utt_id]
#     215
#     216     def get_conversation(self, convo_id: str) -> Conversation:
#
# KeyError: '53453'

# %%
multiple_annots = ['constructiveclass', 'sd_agreement', 'sd_type', 'sentiment', 'tone', 'commentagreement', 'topic',
                  'intendedaudience', 'persuasiveness']
for row in expert_annot.iterrows():
    try:
        data = row[1]
        utt = corpus.get_utterance(data.commentid)
        utt.meta['thumbs-up'] = data['thumbs-up']
        utt.meta['thumbs-down'] = data['thumbs-down']
        if multiple_annots[0] not in utt.meta:
            for k in multiple_annots:
                utt.meta[k] = []

        for k in multiple_annots:
            utt.meta[k].append(data[k])
    except KeyError:
        print("Skipped utterance " + data.commentid)
# Out:
# Skipped utterance 00009g000000000000000000000000-21de97e5-54dd-4dde-a162-b3e0d12164aa
# Skipped utterance 00006g000000000000000000000000-6c9d9a6c-922c-4bbe-a962-00e949fbdb68
# Skipped utterance 00008b000000000000000000000000-5ae4d4da-d334-4a66-99fd-f05873361f0d
# Skipped utterance 00007n000000000000000000000000-e3096a96-0717-4267-a982-e05ccd54e67f
# Skipped utterance 00007n000000000000000000000000-e3096a96-0717-4267-a982-e05ccd54e67f
# Skipped utterance 00006g000000000000000000000000-6c9d9a6c-922c-4bbe-a962-00e949fbdb68
# Skipped utterance 00009g000000000000000000000000-21de97e5-54dd-4dde-a162-b3e0d12164aa
# Skipped utterance 00008b000000000000000000000000-5ae4d4da-d334-4a66-99fd-f05873361f0d
# Skipped utterance 00007n000000000000000000000000-e3096a96-0717-4267-a982-e05ccd54e67f
# Skipped utterance 00006g000000000000000000000000-6c9d9a6c-922c-4bbe-a962-00e949fbdb68
# Skipped utterance 00009g000000000000000000000000-21de97e5-54dd-4dde-a162-b3e0d12164aa
# Skipped utterance 00008b000000000000000000000000-5ae4d4da-d334-4a66-99fd-f05873361f0d

# %%
# Removing nans
for utt in corpus.iter_utterances():
    for k in multiple_annots:
        utt.meta[k] = [v for v in utt.meta[k] if (isinstance(v, str))]

# %%
for utt in corpus.iter_utterances():
    if math.isnan(utt.meta['thumbs-up']):
        utt.meta['thumbs-up'] = None
    if math.isnan(utt.meta['thumbs-down']):
        utt.meta['thumbs-down'] = None

# %%
corpus.random_utterance().meta
# Out:
# {'thumbs-up': 1.0,
#  'thumbs-down': 5.0,
#  'constructiveclass': ['Constructive', 'Constructive', 'Not constructive'],
#  'sd_agreement': ['Continual disagreement',
#   'Initial disagreement converging to agreement'],
#  'sd_type': ['Argumentative (back and forth),Snarky/humorous,Off-topic/digression,Positive/respectful',
#   'Argumentative (back and forth),Off-topic/digression'],
#  'sentiment': ['negative', 'negative', 'negative'],
#  'tone': ['Mean', 'Controversial', 'Mean'],
#  'commentagreement': ['Disagreement with commenter',
#   'Disagreement with commenter',
#   'Disagreement with commenter'],
#  'topic': ['Off-topic with article'],
#  'intendedaudience': ['Reply to a specific commenter',
#   'Reply to a specific commenter',
#   'Reply to a specific commenter'],
#  'persuasiveness': ['Not persuasive', 'Not persuasive', 'Not persuasive']}

# %%
corpus.dump('annotated-ynacc', base_path='.')

# %%
import os
os.listdir()
from convokit import Corpus

# %%
os.listdir()
# Out:
# ['ydata-ynacc-v1_0',
#  'ynacc-turk-conversion.ipynb',
#  '.ipynb_checkpoints',
#  'ynacc-expert-conversion.ipynb']

# %%
corpus = Corpus('ydata-ynacc-v1_0/expert-ynacc')

# %%
corpus.print_summary_stats()
# Out:
# Number of Speakers: 6402
# Number of Utterances: 9156
# Number of Conversations: 1399

# %%
for convo in co

# %%
for convo in corpus.iter_conversations():
    convo.meta['length'] = len(list(convo.iter_utterances()))

# %%
convo_df = corpus.get_conversations_dataframe()

# %%
import seaborn as sns

# %%
sum(convo_df['meta.length'] >= 5)
# Out:
# 1111

# %%
sns.countplot(convo_df['meta.length'])
