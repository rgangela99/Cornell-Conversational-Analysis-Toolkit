# %%
import convokit

# %%
from convokit import Corpus

# %%
c = Corpus(filename="/Users/calebchiam/Desktop/change-my-view-corpus")
# Out:
# ('op-userID', 'bin')
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# Adding to convo meta now
# ...

# %%
next(c.iter_conversations()).meta
# Out:
# {'op-userID': 0    seanyowens
#  Name: op_author, dtype: object,
#  'op-text-body': 0    I can't remember the topic that spurred this d...
#  Name: op_text, dtype: object,
#  'op-title': 0    CMV: Anything that is man-made is natural.
#  Name: op_title, dtype: object,
#  'pair_ids': 0    [p_1]
#  Name: pIDs, dtype: object}
